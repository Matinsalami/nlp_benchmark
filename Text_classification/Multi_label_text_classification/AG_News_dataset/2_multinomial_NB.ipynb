# %% [markdown]
# # In this model we use Multinomial Naive_Bayes for text_classification

# %% [markdown]
# # 1. Load the dataset and devide it into training and test set

# %%
from datasets import load_dataset

ds = load_dataset("ag_news")
train_texts = ds["train"]["text"]
train_labels = ds["train"]["label"]

test_texts = ds["test"]["text"]
test_labels = ds["test"]["label"]

# %%
from sklearn.model_selection import train_test_split

train_texts, val_texts, train_labels, val_labels = train_test_split(train_texts,train_labels,stratify=train_labels,test_size=0.2)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, make_scorer

# TF-IDF + Multinomial NB pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('clf', MultinomialNB())
])

# Hyperparameter grid
param_grid = {
    'tfidf__ngram_range': [(1,1), (1,2)],
    'tfidf__max_features': [20000, 40000, 60000],
    'tfidf__min_df': [1, 2, 3],
    'tfidf__max_df': [0.9, 0.95, 1.0],
    'clf__alpha': [0.1, 0.5, 1.0]
}

# Use macro F1 as the scoring metric
scorer = make_scorer(f1_score, average='macro')

grid = GridSearchCV(
    pipeline,
    param_grid,
    cv=3,
    n_jobs=1,
    scoring=scorer,
    verbose=2
)

grid.fit(train_texts, train_labels)

print("Best params:", grid.best_params_)
print("Best CV score:", grid.best_score_)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=  11.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   4.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.8s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=  10.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.8s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=  10.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.8s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.7s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=0.1, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=  10.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   4.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=  10.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=  10.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   4.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   7.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   7.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   7.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   2.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=  10.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   7.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.5, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.4s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.5s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.5s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=  10.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.5s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.0s
# [CV] END clf__alpha=0.5, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.0s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# ...
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.9, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   4.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   4.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=  11.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=  11.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=  10.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   4.0s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=0.95, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   8.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=20000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.0s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=40000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.1s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.3s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.0s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   8.9s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   9.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.6s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.7s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   9.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.2s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 1); total time=   3.4s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.8s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.5s
# [CV] END clf__alpha=1.0, tfidf__max_df=1.0, tfidf__max_features=60000, tfidf__min_df=3, tfidf__ngram_range=(1, 2); total time=   9.4s
# Best params: {'clf__alpha': 0.1, 'tfidf__max_df': 0.9, 'tfidf__max_features': 60000, 'tfidf__min_df': 1, 'tfidf__ngram_range': (1, 2)}
# Best CV score: 0.9120274319272491

# %%
preds = grid.best_estimator_.predict(test_texts)
f1_score = f1_score(y_true=test_labels,y_pred=preds,average="macro")

# %%
print(f"With Multinomial_NB, we get {(f1_score * 100):.3} f1_score")
# Out:
# With Multinomial_NB, we get 90.9 f1_score
